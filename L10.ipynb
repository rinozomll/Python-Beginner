# %%
! pip install tflearn
! pip install tqdm
! pip install tensorflow
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for tflearn: filename=tflearn-0.5.0-py3-none-any.whl size=127291 sha256=babe3771194c7f957712e9eae8b7174eb5561e68ad22448e8ac143d71973e3e5
#   Stored in directory: c:\users\李國隆\appdata\local\pip\cache\wheels\2e\5f\cd\ffa06b65baff30574958318ce36ef9ef7af1ef3745dadaf420
# Successfully built tflearn
# ...
#   DEPRECATION: Building 'tflearn' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'tflearn'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# ...

# %%
! pip uninstall tensorflow
! pip install tensorflow==1.14
